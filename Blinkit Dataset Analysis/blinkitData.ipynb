# %%
import pandas as pd
import numpy as np

# %%
# read the csv file
blinkitDataC = pd.read_csv('blinkit_customers.csv')
blinkitDataC.head()
# Out:
#    customer_id  customer_name                     email          phone  \
# 0     97475543  Niharika Nagi    ektataneja@example.org  91 2987579691
# 1     22077605   Megha Sachar      vedant45@example.com   915123000000
# 2     47822591     Hema Bahri     samiazaan@example.com   910034000000
# 3     79726146     Zaitra Vig     ishanvi87@example.org   916264000000
# 4     57102800   Januja Verma  atideshpande@example.org   917294000000
#
#                                address          area  pincode  \
# 0  23, Nayar Path, Bihar Sharif-154625         Udupi   321865
# 1  51/302, Buch Chowk\nSrinagar-570271       Aligarh   149394
# 2   941\nAnne Street, Darbhanga 186125     Begusarai   621411
# 3       43/94, Ghosh, Alappuzha 635655     Kozhikode   826054
# 4             06\nOm, Ambarnath 477463  Ichalkaranji   730539
#
#   registration_date customer_segment  total_orders  avg_order_value
# 0        13-05-2023          Premium            13           451.92
# ...

# %%
# read the csv file
blinkitDataO =pd.read_csv('blinkit_orders.csv')
blinkitDataO.head()
# Out:
#      order_id  customer_id        order_date promised_delivery_time  \
# 0  1961864118     30065862  17-07-2024 08:34       17-07-2024 08:52
# 1  1549769649      9573071  28-05-2024 13:14       28-05-2024 13:25
# 2  9185164487     45477575  23-09-2024 13:07       23-09-2024 13:25
# 3  9644738826     88067569  24-11-2023 16:16       24-11-2023 16:34
# 4  5427684290     83298567  20-11-2023 05:00       20-11-2023 05:17
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0     17-07-2024 08:47         On Time      3197.07           Cash
# 1     28-05-2024 13:27         On Time       976.55           Cash
# 2     23-09-2024 13:29         On Time       839.05            UPI
# 3     24-11-2023 16:33         On Time       440.23           Card
# 4     20-11-2023 05:18         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# 2                39859      9886
# ...

# %%
blinkitDataC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        2500 non-null   int64
#  1   customer_name      2500 non-null   object
#  2   email              2500 non-null   object
#  3   phone              2500 non-null   object
#  4   address            2500 non-null   object
#  5   area               2500 non-null   object
#  6   pincode            2500 non-null   int64
#  7   registration_date  2500 non-null   object
#  8   customer_segment   2500 non-null   object
#  9   total_orders       2500 non-null   int64
#  10  avg_order_value    2500 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 215.0+ KB

# %%
blinkitDataC.isnull().sum()
# Out:
# customer_id          0
# customer_name        0
# email                0
# phone                0
# address              0
# area                 0
# pincode              0
# registration_date    0
# customer_segment     0
# total_orders         0
# avg_order_value      0
# dtype: int64

# %%
blinkitDataC.dtypes
# Out:
# customer_id            int64
# customer_name         object
# email                 object
# phone                 object
# address               object
# area                  object
# pincode                int64
# registration_date     object
# customer_segment      object
# total_orders           int64
# avg_order_value      float64
# dtype: object

# %%
blinkitDataC['registration_date'] = pd.to_datetime(blinkitDataC['registration_date'])
# Out:
# C:\Users\MAHENDRA JAIN\AppData\Local\Temp\ipykernel_12628\1021328878.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   blinkitDataC['registration_date'] = pd.to_datetime(blinkitDataC['registration_date'])

# %%
blinkitDataC.head()
# Out:
#    customer_id  customer_name                     email          phone  \
# 0     97475543  Niharika Nagi    ektataneja@example.org  91 2987579691
# 1     22077605   Megha Sachar      vedant45@example.com   915123000000
# 2     47822591     Hema Bahri     samiazaan@example.com   910034000000
# 3     79726146     Zaitra Vig     ishanvi87@example.org   916264000000
# 4     57102800   Januja Verma  atideshpande@example.org   917294000000
#
#                                address          area  pincode  \
# 0  23, Nayar Path, Bihar Sharif-154625         Udupi   321865
# 1  51/302, Buch Chowk\nSrinagar-570271       Aligarh   149394
# 2   941\nAnne Street, Darbhanga 186125     Begusarai   621411
# 3       43/94, Ghosh, Alappuzha 635655     Kozhikode   826054
# 4             06\nOm, Ambarnath 477463  Ichalkaranji   730539
#
#   registration_date customer_segment  total_orders  avg_order_value
# 0        2023-05-13          Premium            13           451.92
# ...

# %%
blinkitDataC['phone'] = blinkitDataC['phone'].str.replace(' ', '',regex=False)
blinkitDataC['phone'] = pd.to_numeric(blinkitDataC['phone'])

# %%
blinkitDataC.dtypes
# Out:
# customer_id                   int64
# customer_name                object
# email                        object
# phone                         int64
# address                      object
# area                         object
# pincode                       int64
# registration_date    datetime64[ns]
# customer_segment             object
# total_orders                  int64
# avg_order_value             float64
# dtype: object

# %%
blinkitDataO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                5000 non-null   int64
#  1   customer_id             5000 non-null   int64
#  2   order_date              5000 non-null   object
#  3   promised_delivery_time  5000 non-null   object
#  4   actual_delivery_time    5000 non-null   object
#  5   delivery_status         5000 non-null   object
#  6   order_total             5000 non-null   float64
#  7   payment_method          5000 non-null   object
#  8   delivery_partner_id     5000 non-null   int64
#  9   store_id                5000 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 390.8+ KB

# %%
blinkitDataO.head()
# Out:
#      order_id  customer_id        order_date promised_delivery_time  \
# 0  1961864118     30065862  17-07-2024 08:34       17-07-2024 08:52
# 1  1549769649      9573071  28-05-2024 13:14       28-05-2024 13:25
# 2  9185164487     45477575  23-09-2024 13:07       23-09-2024 13:25
# 3  9644738826     88067569  24-11-2023 16:16       24-11-2023 16:34
# 4  5427684290     83298567  20-11-2023 05:00       20-11-2023 05:17
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0     17-07-2024 08:47         On Time      3197.07           Cash
# 1     28-05-2024 13:27         On Time       976.55           Cash
# 2     23-09-2024 13:29         On Time       839.05            UPI
# 3     24-11-2023 16:33         On Time       440.23           Card
# 4     20-11-2023 05:18         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# 2                39859      9886
# ...

# %%
blinkitDataO['order_date'] = pd.to_datetime(blinkitDataO['order_date'], format= '%d-%m-%Y %H:%M')
blinkitDataO['promised_delivery_time'] = pd.to_datetime(blinkitDataO['promised_delivery_time'], format= '%d-%m-%Y %H:%M')
blinkitDataO['actual_delivery_time'] = pd.to_datetime(blinkitDataO['actual_delivery_time'], format= '%d-%m-%Y %H:%M')

# %%
blinkitDataO.dtypes
# Out:
# order_id                           int64
# customer_id                        int64
# order_date                datetime64[ns]
# promised_delivery_time    datetime64[ns]
# actual_delivery_time      datetime64[ns]
# delivery_status                   object
# order_total                      float64
# payment_method                    object
# delivery_partner_id                int64
# store_id                           int64
# dtype: object

# %%
blinkitDataO.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# dtype: int64

# %%
blinkitDataC.head()
# Out:
#    customer_id  customer_name                     email         phone  \
# 0     97475543  Niharika Nagi    ektataneja@example.org  912987579691
# 1     22077605   Megha Sachar      vedant45@example.com  915123000000
# 2     47822591     Hema Bahri     samiazaan@example.com  910034000000
# 3     79726146     Zaitra Vig     ishanvi87@example.org  916264000000
# 4     57102800   Januja Verma  atideshpande@example.org  917294000000
#
#                                address          area  pincode  \
# 0  23, Nayar Path, Bihar Sharif-154625         Udupi   321865
# 1  51/302, Buch Chowk\nSrinagar-570271       Aligarh   149394
# 2   941\nAnne Street, Darbhanga 186125     Begusarai   621411
# 3       43/94, Ghosh, Alappuzha 635655     Kozhikode   826054
# 4             06\nOm, Ambarnath 477463  Ichalkaranji   730539
#
#   registration_date customer_segment  total_orders  avg_order_value
# 0        2023-05-13          Premium            13           451.92
# ...

# %%
blinkitDataC.groupby('area')['avg_order_value'].sum().sort_values(ascending=False).head(20)
# Out:
# area
# Jalna          22914.43
# Deoghar        19369.26
# Bathinda       19315.79
# Orai           18984.18
# Ghaziabad      18468.41
# Bulandshahr    16497.55
# Tezpur         16477.24
# Nandyal        16344.13
# Ratlam         15945.66
# Ludhiana       15548.06
# Burhanpur      15479.33
# Khammam        15401.28
# Chittoor       15377.76
# Shivpuri       15102.47
# Korba          14923.96
# Kishanganj     14745.71
# Etawah         14663.36
# Gandhinagar    14576.27
# Thane          14417.67
# Bhagalpur      14047.81
# Name: avg_order_value, dtype: float64

# %%
blinkitDataC.groupby('area')[['total_orders','avg_order_value']].sum().sort_values(by='avg_order_value',ascending=False).head(20)
# Out:
#              total_orders  avg_order_value
# area
# Jalna                 175         22914.43
# Deoghar               200         19369.26
# Bathinda              168         19315.79
# Orai                  190         18984.18
# Ghaziabad             139         18468.41
# Bulandshahr           150         16497.55
# Tezpur                120         16477.24
# Nandyal               162         16344.13
# Ratlam                161         15945.66
# Ludhiana              140         15548.06
# Burhanpur             159         15479.33
# Khammam                72         15401.28
# Chittoor              163         15377.76
# Shivpuri              144         15102.47
# Korba                 160         14923.96
# Kishanganj            153         14745.71
# Etawah                117         14663.36
# Gandhinagar           143         14576.27
# Thane                 117         14417.67
# Bhagalpur             145         14047.81

# %%
blinkitDataC.groupby('area')['avg_order_value'].sum().sort_values(ascending=True).head(20)
# Out:
# area
# Mangalore          330.22
# Srikakulam        1743.97
# Muzaffarpur       2001.14
# Davanagere        2196.57
# Jalandhar         2248.56
# Kurnool           2744.28
# Cuttack           2757.62
# Ozhukarai         2757.80
# Sri Ganganagar    2967.42
# Surat             3094.46
# Phusro            3387.70
# Hyderabad         3397.17
# Shimla            3419.11
# Bokaro            3672.76
# Moradabad         3781.01
# Vasai-Virar       3882.24
# Rourkela          3937.32
# Berhampore        4065.62
# Gopalpur          4116.70
# Raipur            4118.89
# Name: avg_order_value, dtype: float64

# %%
blinkitDataC.groupby('area')[['total_orders','avg_order_value']].sum().sort_values(by='total_orders',ascending=True).head(20)
# Out:
#                 total_orders  avg_order_value
# area
# Mangalore                  3           330.22
# Moradabad                 15          3781.01
# Muzaffarpur               15          2001.14
# Jalandhar                 15          2248.56
# Nashik                    16          4617.49
# Kurnool                   21          2744.28
# Barasat                   26          4279.43
# Rourkela                  26          3937.32
# Kollam                    26          6296.05
# Munger                    27          5536.68
# Phusro                    27          3387.70
# Sri Ganganagar            29          2967.42
# Kulti                     29          6254.24
# Cuttack                   30          2757.62
# Raichur                   31          4214.09
# Davanagere                32          2196.57
# Sirsa                     33          7761.86
# Gurgaon                   34          4601.01
# Bharatpur                 34          4340.17
# ...

# %%
blinkitDataC.groupby('customer_segment').size().sort_values(ascending=False)
# Out:
# customer_segment
# Regular     639
# Premium     633
# New         628
# Inactive    600
# dtype: int64

# %%
blinkitDataC[['total_orders','avg_order_value']].describe()
# Out:
#        total_orders  avg_order_value
# count   2500.000000      2500.000000
# mean      10.491600      1102.375836
# std        5.805533       523.043183
# min        1.000000       200.430000
# 25%        6.000000       631.817500
# 50%       10.000000      1118.650000
# 75%       16.000000      1565.400000
# max       20.000000      1999.830000

# %%
blinkitDataO.head()
# Out:
#      order_id  customer_id          order_date promised_delivery_time  \
# 0  1961864118     30065862 2024-07-17 08:34:00    2024-07-17 08:52:00
# 1  1549769649      9573071 2024-05-28 13:14:00    2024-05-28 13:25:00
# 2  9185164487     45477575 2024-09-23 13:07:00    2024-09-23 13:25:00
# 3  9644738826     88067569 2023-11-24 16:16:00    2023-11-24 16:34:00
# 4  5427684290     83298567 2023-11-20 05:00:00    2023-11-20 05:17:00
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0  2024-07-17 08:47:00         On Time      3197.07           Cash
# 1  2024-05-28 13:27:00         On Time       976.55           Cash
# 2  2024-09-23 13:29:00         On Time       839.05            UPI
# 3  2023-11-24 16:33:00         On Time       440.23           Card
# 4  2023-11-20 05:18:00         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# 2                39859      9886
# ...

# %%
blinkitDataO['order_total'].describe()
# Out:
# count    5000.00000
# mean     2201.86170
# std      1303.02438
# min        13.25000
# 25%      1086.21500
# 50%      2100.69000
# 75%      3156.88250
# max      6721.46000
# Name: order_total, dtype: float64

# %%
blinkitDataO.groupby('delivery_status').size()
# Out:
# delivery_status
# On Time                  3470
# Significantly Delayed     493
# Slightly Delayed         1037
# dtype: int64

# %%
blinkitDataO['delivery_time'] = blinkitDataO['actual_delivery_time'] - blinkitDataO['promised_delivery_time']

# %%
blinkitDataO['delivery_time_diff_minutes'] = blinkitDataO['delivery_time'].dt.total_seconds() / 60

# %%
blinkitDataO
# Out:
#         order_id  customer_id          order_date promised_delivery_time  \
# 0     1961864118     30065862 2024-07-17 08:34:00    2024-07-17 08:52:00
# 1     1549769649      9573071 2024-05-28 13:14:00    2024-05-28 13:25:00
# 2     9185164487     45477575 2024-09-23 13:07:00    2024-09-23 13:25:00
# 3     9644738826     88067569 2023-11-24 16:16:00    2023-11-24 16:34:00
# 4     5427684290     83298567 2023-11-20 05:00:00    2023-11-20 05:17:00
# ...          ...          ...                 ...                    ...
# 4995  1669690997     62600289 2023-12-25 15:46:00    2023-12-25 16:05:00
# 4996  8340761903     53640286 2023-11-27 09:18:00    2023-11-27 09:38:00
# 4997  5936301790     87059497 2024-06-21 19:09:00    2024-06-21 19:23:00
# 4998  5710579377     67310893 2024-06-06 14:58:00    2024-06-06 15:12:00
# 4999  2494813730     28663279 2023-08-23 12:04:00    2023-08-23 12:20:00
#
#      actual_delivery_time delivery_status  order_total payment_method  \
# ...

# %%
blinkitDataO.groupby('payment_method').size().sort_values(ascending=False)
# Out:
# payment_method
# Card      1285
# Cash      1257
# Wallet    1244
# UPI       1214
# dtype: int64

# %%
blinkitDataOSignificantlyDelayed = blinkitDataO[blinkitDataO['delivery_status']== 'Significantly Delayed']

# %%
blinkitDataOSignificantlyDelayed
# Out:
#         order_id  customer_id          order_date promised_delivery_time  \
# 23    6905293278     97259564 2024-06-16 10:23:00    2024-06-16 10:36:00
# 31    9073572548     97111069 2023-05-02 23:13:00    2023-05-02 23:25:00
# 62    2149289255     57579640 2024-11-01 15:00:00    2024-11-01 15:20:00
# 70    2122832513     55028958 2024-02-17 19:48:00    2024-02-17 19:58:00
# 76    5127172657     32293017 2024-06-11 18:11:00    2024-06-11 18:30:00
# ...          ...          ...                 ...                    ...
# 4919  2886463378      6853981 2023-12-24 19:17:00    2023-12-24 19:31:00
# 4937  6999330116     81605722 2023-04-13 00:06:00    2023-04-13 00:24:00
# 4952  4305377896     19216141 2024-08-08 00:29:00    2024-08-08 00:45:00
# 4971  6457122136     79764458 2023-05-19 07:38:00    2023-05-19 07:54:00
# 4984  2520527893     51476157 2024-10-02 01:35:00    2024-10-02 01:53:00
#
#      actual_delivery_time        delivery_status  order_total payment_method  \
# ...

# %%
blinkitDataO.groupby('delivery_status').size()
# Out:
# delivery_status
# On Time                  3470
# Significantly Delayed     493
# Slightly Delayed         1037
# dtype: int64

# %%
ratioOfDeliveryStatus = (blinkitDataO.groupby('delivery_status').size()/blinkitDataO.groupby('delivery_status').size().sum())*100

# %%
ratioOfDeliveryStatus
# Out:
# delivery_status
# On Time                  69.40
# Significantly Delayed     9.86
# Slightly Delayed         20.74
# dtype: float64

# %%
blinkitCustomerOrder = pd.merge(blinkitDataC,blinkitDataO, on='customer_id',how='inner')
blinkitCustomerOrder
# Out:
#       customer_id    customer_name                    email         phone  \
# 0        97475543    Niharika Nagi   ektataneja@example.org  912987579691
# 1        97475543    Niharika Nagi   ektataneja@example.org  912987579691
# 2        97475543    Niharika Nagi   ektataneja@example.org  912987579691
# 3        97475543    Niharika Nagi   ektataneja@example.org  912987579691
# 4        22077605     Megha Sachar     vedant45@example.com  915123000000
# ...           ...              ...                      ...           ...
# 4995     57392064     Lavanya Jain  deshpandeom@example.com  916137000000
# 4996     57392064     Lavanya Jain  deshpandeom@example.com  916137000000
# 4997     57392064     Lavanya Jain  deshpandeom@example.com  916137000000
# 4998     57392064     Lavanya Jain  deshpandeom@example.com  916137000000
# 4999     89051578  Zinal Natarajan    vyasfrado@example.com  911994000000
#
#                                            address     area  pincode  \
# ...
